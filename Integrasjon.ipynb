# %%
import math as m

def dx(a, b, n, r):
    a, b, n, r = float(a), float(b), int(n), float(r)

    g = input("f(x) = ")
    f = lambda x: eval(g)

    delta = (b - a) / n
    sum = 0

    for i in range(n):
        sum += f(a + (i + r) * delta) * delta
    print(f"Riemannsum: {sum}")

dx(input("Startverdi:"), input("Sluttverdi:"), input("Antall søyler:"), input("Avstand mellom xi og x* [0, 1]:"))
# Out:
# Riemannsum: 7.621371056244299

# %%
import math as m

def dx(a, b, n):
    a, b, n = float(a), float(b), int(n)

    g = input("f(x) = ")
    f = lambda x: eval(g)

    delta = (b - a) / n
    sum = 0

    for i in range(n):
        sum += (f(a + i * delta) + f(a + (i + 1) * delta)) / 2 * delta
    print(f"Trapestilnærming: {sum}")

dx(input("Startverdi:"), input("Sluttverdi:"), input("Antall søyler:"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 16
#      13         sum += (f(a + i * delta) + f(a + (i + 1) * delta)) / 2 * delta
#      14     print(f"Trapestilnærming: {sum}")
# ---> 16 dx(input("Startverdi:"), input("Sluttverdi:"), input("Antall søyler:"))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1251, in Kernel.raw_input(self, prompt)
#    1249     msg = "raw_input was called, but this frontend does not support input requests."
#    1250     raise StdinNotImplementedError(msg)
# -> 1251 return self._input_request(
#    1252     str(prompt),
#    1253     self._parent_ident["shell"],
#    1254     self.get_parent("shell"),
#    1255     password=False,
#    1256 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1295, in Kernel._input_request(self, prompt, ident, parent, password)
#    1292 except KeyboardInterrupt:
#    1293     # re-raise KeyboardInterrupt, to truncate traceback
#    1294     msg = "Interrupted by user"
# -> 1295     raise KeyboardInterrupt(msg) from None
#    1296 except Exception:
#    1297     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
